# %% [markdown]
# # **Chilean Recipes**
# I chose this dataset because I like food and I want to discover something interesting about Chilean recipes. I'm not sure what I might find, but whatever it is, I will find it.

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/BBDD/chilean_recipes.csv"
import pandas as pd
df = pd.read_csv(path)
# Out:
# Mounted at /content/drive

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace(r'[^\w]', '', regex=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   recipe_name       117 non-null    object
#  1   preparation_time  117 non-null    float64
#  2   min_portion       101 non-null    float64
#  3   max_portion       14 non-null     float64
#  4   ingredients       117 non-null    object
#  5   steps             117 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 5.6+ KB

# %%
df.head()
# Out:
#                           recipe_name  preparation_time  min_portion  \
# 0                      Ajiaco chileno              40.0          3.0
# 1                  Alfajores chilenos              40.0         20.0
# 2                Alfajores de Maicena              30.0         20.0
# 3                      Aliño completo               5.0          NaN
# 4  Anticuchos de carne y vegetarianos              30.0          4.0
#
#    max_portion                                        ingredients  \
# 0          4.0  ['300 grs de carne asada, puede ser más', '2 c...
# 1          NaN  ['1 1/2 taza de harina cernida', '5 yemas', '1...
# 2          NaN  ['125 grs. margarina', '150 grs. azúcar flor (...
# 3          NaN  ['1 cucharada de ajo en polvo', '1 cucharada d...
# 4          6.0  ['1/2 kilo de carne para la parrilla (lomo vet...
#
#                                                steps
# 0  ['1-Cortamos la carne en tiras y las papas a l...
# ...

# %%
df.tail()
# Out:
#                             recipe_name  preparation_time  min_portion  \
# 112               Tortilla de zanahoria              18.0          2.0
# 113        Tortilla de zapallo italiano              25.0          2.0
# 114                      Turrón de vino               0.0          6.0
# 115             Vaina, cocktail chileno              10.0          1.0
# 116  Zapallo italiano relleno con pollo              45.0          2.0
#
#      max_portion                                        ingredients  \
# 112          NaN  ['4 zanahorias sin cáscara', '1/2 unidad de ce...
# 113          NaN  ['2 zapallos italianos', '1/2 unidad de ceboll...
# 114          8.0  ['1 taza de azúcar', '1/2 taza de vino tinto',...
# 115          NaN  ['50 cc de vino añejo u oporto', '30 cc de Cog...
# 116          NaN  ['PARA LOS ZAPALLOS', '2 zapallitos italianos'...
#
#                                                  steps
# 112  ['1-En una sartén freír la cebolla con la cuch...
# ...

# %%
# Basic descriptive statistics for numerical columns
df[['preparation_time', 'min_portion', 'max_portion']].describe().T
# Out:
#                   count       mean        std  min   25%   50%   75%    max
# preparation_time  117.0  37.521368  33.675070  0.0  10.0  35.0  50.0  150.0
# min_portion       101.0   8.722772   7.336374  1.0   4.0   6.0  12.0   40.0
# max_portion        14.0   9.428571   8.196756  3.0   4.0   7.0   9.5   30.0

# %%
df['portion_range'].describe().T
# Out:
# count    14.000000
# mean      2.000000
# std       1.240347
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max       5.000000
# Name: portion_range, dtype: float64

# %%
df['num_ingredients'] = df['ingredients'].str.split(',').apply(len)
df['num_steps'] = df['steps'].str.split('.').apply(len)

df[['num_ingredients', 'num_steps']].describe().T
# Out:
#                  count       mean       std  min  25%   50%   75%   max
# num_ingredients  117.0  10.179487  4.496388  1.0  7.0   9.0  14.0  22.0
# num_steps        117.0  11.239316  5.346042  1.0  8.0  12.0  14.0  28.0
